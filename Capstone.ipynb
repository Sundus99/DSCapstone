# %% [markdown]
# # Capstone
# **Author:** Sundus Yawar
# **Student ID:** 583854
# **Institute:** BrainStation
# **Capstone Supervisor:** Amir Rahimizadeh

# %% [markdown]
# # Importing Data

# %%
import pandas as pd

# %% [markdown]
# Initially, when I imported the data it was showing many columns (empty columns), I did df.shape and it showed (1323,222) but I know that my dataset only has 15 columns.
# I figured that it probably imported that way because I have heading in 2 rows where main heading is in 1st row and subheading is in 2nd row. When there is a subheading the first row is usually empty. This, confuses the import statement into thinking empty cell is considered as column which is why I had that problem. So, I decided to import just the actual data and then add the column headers later.

# %%
#TEST
df = pd.read_csv('MY2017 Fuel Consumption Ratings.csv', header=None, skiprows=[0, 1],encoding='iso-8859-1')
headers = ["Model_Year", "Make", "Model", "Vehicle_Class", "Engine_Size(L)", "Cylinders", "Transmission", "Fuel_Type", "Fuel_Consumption-City(L/100 km)", "Fuel_Consumption-Hwy(L/100 km)", "Fuel_Consumption-Comb(L/100 km)", "Fuel_Consumption-Comb(mpg)", "CO2_Emissions(g/km)", "CO2_Rating", "Smog_Rating"]
df.columns = headers
df.head()
# Out:
#   Model_Year   Make             Model Vehicle_Class  Engine_Size(L)  \
# 0       2017  ACURA               ILX       COMPACT             2.4
# 1       2017  ACURA        MDX SH-AWD   SUV - SMALL             3.5
# 2       2017  ACURA  MDX SH-AWD ELITE   SUV - SMALL             3.5
# 3       2017  ACURA    MDX HYBRID AWD   SUV - SMALL             3.0
# 4       2017  ACURA               NSX    TWO-SEATER             3.5
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AM8         Z                              9.4
# 1        6.0          AS9         Z                             12.6
# 2        6.0          AS9         Z                             12.2
# 3        6.0          AM7         Z                              9.1
# 4        6.0          AM9         Z                             11.1
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             6.8                              8.2
# 1                             9.0                             11.0
# 2                             9.0                             10.7
# 3                             9.0                              9.0
# 4                            10.8                             11.0
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        34.0                192.0         7.0          6.0
# 1                        26.0                259.0         4.0          6.0
# 2                        26.0                251.0         5.0          6.0
# 3                        31.0                210.0         6.0          6.0
# 4                        26.0                261.0         4.0          6.0

# %%
df.shape
# Out:
# (1086, 15)

# %%
dataframes = {}
headers = ["Model_Year", "Make", "Model", "Vehicle_Class", "Engine_Size(L)", "Cylinders", "Transmission", "Fuel_Type", "Fuel_Consumption-City(L/100 km)", "Fuel_Consumption-Hwy(L/100 km)", "Fuel_Consumption-Comb(L/100 km)", "Fuel_Consumption-Comb(mpg)", "CO2_Emissions(g/km)", "CO2_Rating", "Smog_Rating"]
#I had to specify number of columns to import because it was importing empty columns too (221 columns rather than 15)
for year in range(2017, 2024):
    file_path = 'MY{} Fuel Consumption Ratings.csv'.format(year)
    dataframes[year] = pd.read_csv(file_path, header=None, skiprows=[0, 1], encoding='iso-8859-1', usecols=range(15))
# Out:
# c:\Users\Sundus Yawar\anaconda3\envs\myenv\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (0,1,2,3,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
for year in range(2017,2024):
    print(dataframes[year].head())
# Out:
#   Model_Year   Make             Model Vehicle_Class  Engine_Size(L)  \
# 0       2017  ACURA               ILX       COMPACT             2.4
# 1       2017  ACURA        MDX SH-AWD   SUV - SMALL             3.5
# 2       2017  ACURA  MDX SH-AWD ELITE   SUV - SMALL             3.5
# 3       2017  ACURA    MDX HYBRID AWD   SUV - SMALL             3.0
# 4       2017  ACURA               NSX    TWO-SEATER             3.5
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AM8         Z                              9.4
# 1        6.0          AS9         Z                             12.6
# 2        6.0          AS9         Z                             12.2
# 3        6.0          AM7         Z                              9.1
# 4        6.0          AM9         Z                             11.1
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             6.8                              8.2
# 1                             9.0                             11.0
# 2                             9.0                             10.7
# 3                             9.0                              9.0
# 4                            10.8                             11.0
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        34.0                192.0         7.0          6.0
# 1                        26.0                259.0         4.0          6.0
# 2                        26.0                251.0         5.0          6.0
# 3                        31.0                210.0         6.0          6.0
# 4                        26.0                261.0         4.0          6.0
#   Model_Year   Make             Model Vehicle_Class  Engine_Size(L)  \
# 0       2018  Acura               ILX       Compact             2.4
# 1       2018  Acura        MDX SH-AWD    SUV: Small             3.5
# 2       2018  Acura  MDX SH-AWD Elite    SUV: Small             3.5
# 3       2018  Acura    MDX Hybrid AWD    SUV: Small             3.0
# 4       2018  Acura               NSX    Two-seater             3.5
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AM8         Z                              9.4
# 1        6.0          AS9         Z                             12.6
# 2        6.0          AS9         Z                             12.2
# 3        6.0          AM7         Z                              9.1
# 4        6.0          AM9         Z                             11.1
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             6.8                              8.2
# 1                             9.0                             11.0
# 2                             9.0                             10.7
# 3                             9.0                              9.0
# 4                            10.8                             11.0
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        34.0                192.0         6.0          3.0
# 1                        26.0                259.0         4.0          3.0
# 2                        26.0                251.0         4.0          3.0
# 3                        31.0                210.0         5.0          3.0
# 4                        26.0                261.0         4.0          3.0
#   Model_Year   Make              Model Vehicle_Class  Engine_Size(L)  \
# 0       2019  Acura                ILX       Compact             2.4
# 1       2019  Acura         MDX SH-AWD    SUV: Small             3.5
# 2       2019  Acura  MDX SH-AWD A-SPEC    SUV: Small             3.5
# 3       2019  Acura     MDX Hybrid AWD    SUV: Small             3.0
# 4       2019  Acura                NSX    Two-seater             3.5
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AM8         Z                              9.9
# 1        6.0          AS9         Z                             12.2
# 2        6.0          AS9         Z                             12.2
# 3        6.0          AM7         Z                              9.1
# 4        6.0          AM9         Z                             11.1
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             7.0                              8.6
# 1                             9.0                             10.8
# 2                             9.5                             11.0
# 3                             9.0                              9.0
# 4                            10.8                             11.0
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        33.0                199.0         6.0          3.0
# 1                        26.0                252.0         4.0          3.0
# 2                        26.0                258.0         4.0          3.0
# 3                        31.0                210.0         5.0          3.0
# 4                        26.0                261.0         4.0          3.0
#   Model_Year   Make              Model Vehicle_Class  Engine_Size(L)  \
# 0       2020  Acura                ILX       Compact             2.4
# 1       2020  Acura         MDX SH-AWD    SUV: Small             3.5
# 2       2020  Acura  MDX SH-AWD A-SPEC    SUV: Small             3.5
# 3       2020  Acura     MDX Hybrid AWD    SUV: Small             3.0
# 4       2020  Acura                NSX    Two-seater             3.5
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AM8         Z                              9.9
# 1        6.0          AS9         Z                             12.3
# 2        6.0          AS9         Z                             12.2
# 3        6.0          AM7         Z                              9.1
# 4        6.0          AM9         Z                             11.1
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             7.0                              8.6
# 1                             9.2                             10.9
# 2                             9.5                             11.0
# 3                             9.0                              9.0
# 4                            10.8                             11.0
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        33.0                199.0         6.0          3.0
# 1                        26.0                254.0         4.0          3.0
# 2                        26.0                258.0         4.0          3.0
# 3                        31.0                210.0         5.0          3.0
# 4                        26.0                261.0         4.0          3.0
#   Model_Year   Make              Model Vehicle_Class  Engine_Size(L)  \
# 0       2021  Acura                ILX       Compact             2.4
# 1       2021  Acura                NSX    Two-seater             3.5
# 2       2021  Acura         RDX SH-AWD    SUV: Small             2.0
# 3       2021  Acura  RDX SH-AWD A-SPEC    SUV: Small             2.0
# 4       2021  Acura         TLX SH-AWD       Compact             2.0
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AM8         Z                              9.9
# 1        6.0          AM9         Z                             11.1
# 2        4.0         AS10         Z                             11.0
# 3        4.0         AS10         Z                             11.3
# 4        4.0         AS10         Z                             11.2
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             7.0                              8.6
# 1                            10.8                             11.0
# 2                             8.6                              9.9
# 3                             9.1                             10.3
# 4                             8.0                              9.8
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        33.0                199.0         6.0          3.0
# 1                        26.0                256.0         4.0          3.0
# 2                        29.0                232.0         5.0          6.0
# 3                        27.0                242.0         5.0          6.0
# 4                        29.0                230.0         5.0          7.0
#   Model_Year   Make       Model  Vehicle_Class  Engine_Size(L)  Cylinders  \
# 0       2022  Acura         ILX        Compact             2.4        4.0
# 1       2022  Acura  MDX SH-AWD     SUV: Small             3.5        6.0
# 2       2022  Acura  MDX Type S  SUV: Standard             3.0        6.0
# 3       2022  Acura         NSX     Two-seater             3.5        6.0
# 4       2022  Acura  RDX SH-AWD     SUV: Small             2.0        4.0
#
#   Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0          AM8         Z                              9.9
# 1         AS10         Z                             12.6
# 2         AS10         Z                             13.8
# 3          AM9         Z                             11.1
# 4         AS10         Z                             11.0
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             7.0                              8.6
# 1                             9.4                             11.2
# 2                            11.2                             12.4
# 3                            10.8                             11.0
# 4                             8.6                              9.9
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        33.0                200.0         6.0          3.0
# 1                        25.0                263.0         4.0          5.0
# 2                        23.0                291.0         4.0          5.0
# 3                        26.0                256.0         5.0          3.0
# 4                        29.0                232.0         5.0          6.0
#   Model_Year   Make              Model  Vehicle_Class  Engine_Size(L)  \
# 0       2023  Acura            Integra      Full-size             1.5
# 1       2023  Acura     Integra A-SPEC      Full-size             1.5
# 2       2023  Acura     Integra A-SPEC      Full-size             1.5
# 3       2023  Acura         MDX SH-AWD     SUV: Small             3.5
# 4       2023  Acura  MDX SH-AWD Type S  SUV: Standard             3.0
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AV7         Z                              7.9
# 1        4.0          AV7         Z                              8.1
# 2        4.0           M6         Z                              8.9
# 3        6.0         AS10         Z                             12.6
# 4        6.0         AS10         Z                             13.8
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             6.3                              7.2
# 1                             6.5                              7.4
# 2                             6.5                              7.8
# 3                             9.4                             11.2
# 4                            11.2                             12.4
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        39.0                167.0         6.0          7.0
# 1                        38.0                172.0         6.0          7.0
# 2                        36.0                181.0         6.0          6.0
# 3                        25.0                263.0         4.0          5.0
# 4                        23.0                291.0         4.0          5.0

# %%
for year in range(2017, 2024):
    df_name = 'fuel_cons_rating_{}'.format(year)
    print(df_name,":\n",dataframes[year].isna().sum(),"\n<=========================>")
# Out:
# fuel_cons_rating_2017 :
#  Model_Year                         18
# Make                                7
# Model                              28
# Vehicle_Class                      28
# Engine_Size(L)                     28
# Cylinders                          28
# Transmission                       28
# Fuel_Type                          28
# Fuel_Consumption-City(L/100 km)    28
# Fuel_Consumption-Hwy(L/100 km)     28
# Fuel_Consumption-Comb(L/100 km)    28
# Fuel_Consumption-Comb(mpg)         28
# CO2_Emissions(g/km)                28
# CO2_Rating                         28
# Smog_Rating                        28
# dtype: int64
# <=========================>
# fuel_cons_rating_2018 :
#  Model_Year                         251
# Make                               238
# Model                              259
# Vehicle_Class                      259
# Engine_Size(L)                     259
# Cylinders                          259
# Transmission                       259
# Fuel_Type                          259
# Fuel_Consumption-City(L/100 km)    259
# Fuel_Consumption-Hwy(L/100 km)     259
# Fuel_Consumption-Comb(L/100 km)    259
# Fuel_Consumption-Comb(mpg)         259
# CO2_Emissions(g/km)                259
# CO2_Rating                         259
# Smog_Rating                        259
# dtype: int64
# <=========================>
# fuel_cons_rating_2019 :
#  Model_Year                         250
# Make                               237
# Model                              258
# Vehicle_Class                      258
# Engine_Size(L)                     258
# Cylinders                          258
# Transmission                       258
# Fuel_Type                          258
# Fuel_Consumption-City(L/100 km)    258
# Fuel_Consumption-Hwy(L/100 km)     258
# Fuel_Consumption-Comb(L/100 km)    258
# Fuel_Consumption-Comb(mpg)         258
# CO2_Emissions(g/km)                258
# CO2_Rating                         258
# Smog_Rating                        258
# dtype: int64
# <=========================>
# fuel_cons_rating_2020 :
#  Model_Year                         4154
# Make                               4141
# Model                              4162
# Vehicle_Class                      4162
# Engine_Size(L)                     4162
# Cylinders                          4162
# Transmission                       4162
# Fuel_Type                          4162
# Fuel_Consumption-City(L/100 km)    4162
# Fuel_Consumption-Hwy(L/100 km)     4162
# Fuel_Consumption-Comb(L/100 km)    4162
# Fuel_Consumption-Comb(mpg)         4162
# CO2_Emissions(g/km)                4162
# CO2_Rating                         4162
# Smog_Rating                        4162
# dtype: int64
# <=========================>
# fuel_cons_rating_2021 :
#  Model_Year                         4150
# Make                               4137
# Model                              4158
# Vehicle_Class                      4158
# Engine_Size(L)                     4158
# Cylinders                          4158
# Transmission                       4158
# Fuel_Type                          4158
# Fuel_Consumption-City(L/100 km)    4158
# Fuel_Consumption-Hwy(L/100 km)     4158
# Fuel_Consumption-Comb(L/100 km)    4158
# Fuel_Consumption-Comb(mpg)         4158
# CO2_Emissions(g/km)                4158
# CO2_Rating                         4158
# Smog_Rating                        4158
# dtype: int64
# <=========================>
# fuel_cons_rating_2022 :
#  Model_Year                         5717
# Make                               5704
# Model                              5725
# Vehicle_Class                      5725
# Engine_Size(L)                     5725
# Cylinders                          5725
# Transmission                       5725
# Fuel_Type                          5725
# Fuel_Consumption-City(L/100 km)    5725
# Fuel_Consumption-Hwy(L/100 km)     5725
# Fuel_Consumption-Comb(L/100 km)    5725
# Fuel_Consumption-Comb(mpg)         5725
# CO2_Emissions(g/km)                5725
# CO2_Rating                         5725
# Smog_Rating                        5725
# dtype: int64
# <=========================>
# fuel_cons_rating_2023 :
#  Model_Year                         6515
# Make                               6502
# Model                              6523
# Vehicle_Class                      6523
# Engine_Size(L)                     6523
# Cylinders                          6523
# Transmission                       6523
# Fuel_Type                          6523
# Fuel_Consumption-City(L/100 km)    6523
# Fuel_Consumption-Hwy(L/100 km)     6523
# Fuel_Consumption-Comb(L/100 km)    6523
# Fuel_Consumption-Comb(mpg)         6523
# CO2_Emissions(g/km)                6523
# CO2_Rating                         6523
# Smog_Rating                        6523
# dtype: int64
# <=========================>

# %% [markdown]
# I feel like getting the isna in a for loop added the na count from previous file so I thought it'd be better to concatenate the files before checking for nulls, performing data cleaning and EDA etc.

# %%
#vertically concatenate (aka stack) the data because it is same thing just for different model year
fuel_cons_rating = pd.concat([dataframes[2017],dataframes[2018],dataframes[2019],dataframes[2020],dataframes[2021],dataframes[2022],dataframes[2023]],axis=0)

# %%
#I am going to add the header now and reset index since multiple files were stacked
fuel_cons_rating.columns = headers
fuel_cons_rating.reset_index(drop=True)
fuel_cons_rating.head()
# Out:
#   Model_Year   Make             Model Vehicle_Class  Engine_Size(L)  \
# 0       2017  ACURA               ILX       COMPACT             2.4
# 1       2017  ACURA        MDX SH-AWD   SUV - SMALL             3.5
# 2       2017  ACURA  MDX SH-AWD ELITE   SUV - SMALL             3.5
# 3       2017  ACURA    MDX HYBRID AWD   SUV - SMALL             3.0
# 4       2017  ACURA               NSX    TWO-SEATER             3.5
#
#    Cylinders Transmission Fuel_Type  Fuel_Consumption-City(L/100 km)  \
# 0        4.0          AM8         Z                              9.4
# 1        6.0          AS9         Z                             12.6
# 2        6.0          AS9         Z                             12.2
# 3        6.0          AM7         Z                              9.1
# 4        6.0          AM9         Z                             11.1
#
#    Fuel_Consumption-Hwy(L/100 km)  Fuel_Consumption-Comb(L/100 km)  \
# 0                             6.8                              8.2
# 1                             9.0                             11.0
# 2                             9.0                             10.7
# 3                             9.0                              9.0
# 4                            10.8                             11.0
#
#    Fuel_Consumption-Comb(mpg)  CO2_Emissions(g/km)  CO2_Rating  Smog_Rating
# 0                        34.0                192.0         7.0          6.0
# 1                        26.0                259.0         4.0          6.0
# 2                        26.0                251.0         5.0          6.0
# 3                        31.0                210.0         6.0          6.0
# 4                        26.0                261.0         4.0          6.0
