# %% [markdown]
# # Capstone
# **Author:** Sundus Yawar
# **Student ID:** 583854
# **Institute:** BrainStation
# **Capstone Supervisor:** Amir Rahimizadeh

# %% [markdown]
# # Importing Data

# %%
import pandas as pd

# %%
df = pd.read_csv('MY2015 Fuel Consumption Ratings.csv', encoding='iso-8859-1')
df.head()
# Out:
#   MODEL   MAKE     MODEL.1 VEHICLE CLASS ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 0  YEAR    NaN         NaN           NaN         (L)        NaN          NaN
# 1  2015  ACURA         ILX       COMPACT         2.0        4.0          AS5
# 2  2015  ACURA         ILX       COMPACT         2.4        4.0           M6
# 3  2015  ACURA  ILX HYBRID       COMPACT         1.5        4.0          AV7
# 4  2015  ACURA  MDX SH-AWD   SUV - SMALL         3.5        6.0          AS6
#
#    FUEL FUEL CONSUMPTION*      Unnamed: 9      Unnamed: 10 Unnamed: 11  \
# 0  TYPE   CITY (L/100 km)  HWY (L/100 km)  COMB (L/100 km)  COMB (mpg)
# 1     Z               9.7             6.7              8.3          34
# 2     Z              10.8             7.4              9.3          30
# 3     Z               6.0             6.1              6.1          46
# 4     Z              12.7             9.1             11.1          25
#
#   CO2 EMISSIONS   Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16
# ...

# %%
dataframes = {}
for year in range(2015, 2024):
    file_path = 'MY{} Fuel Consumption Ratings.csv'.format(year)
    dataframes[year] = pd.read_csv(file_path, encoding='iso-8859-1')
# Out:
# C:\Users\Sundus Yawar\AppData\Local\Temp\ipykernel_41420\3479470965.py:4: DtypeWarning: Columns (0,1,2,3,4,6,7,8,9,10,11,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes[year] = pd.read_csv(file_path, encoding='iso-8859-1')
# C:\Users\Sundus Yawar\AppData\Local\Temp\ipykernel_41420\3479470965.py:4: DtypeWarning: Columns (0,1,2,3,4,6,7,8,9,10,11,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes[year] = pd.read_csv(file_path, encoding='iso-8859-1')
# C:\Users\Sundus Yawar\AppData\Local\Temp\ipykernel_41420\3479470965.py:4: DtypeWarning: Columns (0,1,2,3,4,6,7,8,9,10,11,12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes[year] = pd.read_csv(file_path, encoding='iso-8859-1')
# ...

# %%
fuel_cons_rating_2015 = dataframes[2015] 
fuel_cons_rating_2016 = dataframes[2016]
fuel_cons_rating_2017 = dataframes[2017]
fuel_cons_rating_2018 = dataframes[2018]
fuel_cons_rating_2019 = dataframes[2019]
fuel_cons_rating_2020 = dataframes[2020]
fuel_cons_rating_2021 = dataframes[2021]
fuel_cons_rating_2022 = dataframes[2022]
fuel_cons_rating_2023 = dataframes[2023]

# %%
for year in range(2015, 2024):
    df = 'fuel_cons_rating_{}'.format(year)
    print(df,":\n",dataframes[year].isna().sum(),"\n<=========================>")
# Out:
# fuel_cons_rating_2015 :
#  MODEL                  12
# MAKE                    7
# MODEL.1                22
# VEHICLE CLASS          22
# ENGINE SIZE            21
# CYLINDERS              22
# TRANSMISSION           22
# FUEL                   21
# FUEL CONSUMPTION*      21
# Unnamed: 9             21
# Unnamed: 10            21
# Unnamed: 11            21
# CO2 EMISSIONS          21
# Unnamed: 13          1154
# Unnamed: 14          1154
# Unnamed: 15          1154
# Unnamed: 16          1154
# dtype: int64
# <=========================>
# fuel_cons_rating_2016 :
#  MODEL                254
# MAKE                 244
# MODEL.1              264
# VEHICLE CLASS        264
# ENGINE SIZE          263
# CYLINDERS            264
# TRANSMISSION         264
# FUEL                 263
# FUEL CONSUMPTION     263
# Unnamed: 9           263
# Unnamed: 10          263
# Unnamed: 11          263
# CO2 EMISSIONS        263
# CO2                  263
# Unnamed: 14         1374
# ...
